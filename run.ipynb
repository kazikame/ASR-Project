# %%
from train import train

# %%
model = train()
# Out:
# start
# Output Conv2D: (None, 1, 320, 32)
# Output MaxPool2D: (None, 1, 64, 32)
# Output Conv2D: (None, 1, 60, 64)
# Output MaxPool2D: (None, 1, 12, 64)
# Output Conv2D: (None, 1, 8, 128)
# Output MaxPool2D: (None, 1, 8, 128)
# Output Conv2D: (None, 1, 4, 128)
# Output MaxPool2D: (None, 1, 4, 128)
# Output Flatten: (None, 512)
# Output dense of music: (None, 512)
# Output dense of lyrics: (None, 128)
# Performing batch normalization
# Output final dense: (None, 1024)
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 84, 324, 1)] 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 1, 320, 32)   13472       input_1[0][0]
# ...
